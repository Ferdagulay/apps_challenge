# %%
import os
import base64
import json
import re
import time
import requests
from openai import OpenAI
from PIL import Image
from io import BytesIO

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base
# **User Input:**
#
# + The user uploads an **image** and provides a **prompt** describing what changes should be made to the image.
#
# **Step 1 — Caption Generation (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the **GPT-4o-mini** model.
# + *GPT-4o-mini* analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + This caption includes visual attributes such as colors, drawing style, food category, background, and layout.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the generated caption are merged into a final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
# + DALL·E 3 generates a new image that preserves the style of the original but incorporates the requested modifications.
#
# **Output:**
#
# + A newly generated image that reflects both the original style and the desired changes from the prompt.
# + The output is saved and logged along with the image paths and generated caption.

# %%
API_KEY= "your_api_key"

# Initialize the OpenAI client
client = OpenAI(api_key=API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template = """
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt describing how it should be redesigned.

Task:
Generate a **detailed caption** describing the image. The caption should:
- Include visual details like color, pattern, drawing style, background if visible.
- Analyze the "category"(the general type of food depicted) and describe its key features.
- Be a single sentence, fluent, and descriptive.
- These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.

Output caption example:
"A red "category" and a sliced "category" with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three "category" with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "category": "<your generated food category here>",
  "caption": "<your generated caption here>",
  "image_path": "<actual image path>",
  "user_prompt": "<user prompt>",
  "generated_image_path":"<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    # Read and encode image as base64
    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")
    
    # Format the prompt for GPT
    formatted_prompt = prompt_template.format(user_prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        caption = parsed["caption"]         
        dalle_prompt = user_prompt 
        
        # Create a full prompt for DALL·E using both the caption and user instruction.
        full_prompt = f"{dalle_prompt}, render in the exact same illustration style and details as described: {caption}"

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # Wait to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)
        
        # Download and save the generated image
        os.makedirs("outputs/base_prompt", exist_ok=True)
        generated_image_path = f"outputs/base_prompt/{safe_prompt}_generated.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path
        parsed["user_prompt"] = user_prompt


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")
# Save all results to a JSON file
with open("outputs/base_prompt/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: {
#   "category": "apple",
#   "caption": "A shiny red apple with a vibrant green leaf beside a freshly sliced half, revealing its creamy white flesh and small brown seeds, illustrated in a flat cartoon vector style with soft lighting and vivid colors, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background, render in the exact same illustration style and details as described: A shiny red apple with a vibrant green leaf beside a freshly sliced half, revealing its creamy white flesh and small brown seeds, illustrated in a flat cartoon vector style with soft lighting and vivid colors, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-N7xOQ8oArHgEcTibFd8sYms7.png?st=2025-06-09T06%3A27%3A58Z&se=2025-06-09T08%3A27%3A58Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T08%3A37%3A33Z&ske=2025-06-09T08%3A37%3A33Z&sks=b&skv=2024-08-04&sig=XqBiniARyvnxnjpW3Np4EQP0/RDu//IQ/ZmLpAf3x0I%3D
# Saved generated image to outputs/base_prompt/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background_generated.png
# Processing: test_images/S_02_Apricot.png
# Caption output: {
#   "category": "peach",
#   "caption": "A vibrant orange peach with a smooth surface, featuring a small green leaf and a brown stem, illustrated in a flat cartoon vector style with soft shadows and no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image., render in the exact same illustration style and details as described: A vibrant orange peach with a smooth surface, featuring a small green leaf and a brown stem, illustrated in a flat cartoon vector style with soft shadows and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-NaDmLY4Npg5Yiq2ZvVNp4iVc.png?st=2025-06-09T06%3A28%3A27Z&se=2025-06-09T08%3A28%3A27Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T18%3A57%3A07Z&ske=2025-06-09T18%3A57%3A07Z&sks=b&skv=2024-08-04&sig=3FHtaEgkdJpFSSiWHvQj1LpOOQg2ZUfXEqJur7CEco4%3D
# Saved generated image to outputs/base_prompt/draw_a_shiny_red_apple_with_a_vibrant_green_leaf_in_the_same_digital_illustration_style_as_s_02_apricotpng_the_apple_should_be_centered_well-lit_and_have_soft_shadows_like_the_apricot_image_generated.png
# Processing: test_images/S_03_Avocado_1.png
# Caption output: {
#   "category": "avocado",
#   "caption": "A vibrant green avocado half with a smooth, creamy yellow interior and a round brown pit, illustrated in a flat cartoon vector style with bold outlines and bright colors, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look., render in the exact same illustration style and details as described: A vibrant green avocado half with a smooth, creamy yellow interior and a round brown pit, illustrated in a flat cartoon vector style with bold outlines and bright colors, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-T5PK8ekC8UVpWONIMfrIIrwN.png?st=2025-06-09T06%3A28%3A50Z&se=2025-06-09T08%3A28%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T22%3A13%3A18Z&ske=2025-06-09T22%3A13%3A18Z&sks=b&skv=2024-08-04&sig=AOfuRrVPGr1aVUmefVPFrNfzeh8d/pBC5rQs6EX2pq8%3D
# Saved generated image to outputs/base_prompt/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look_generated.png
# Processing: test_images/04_Banana.png
# Caption output: {
#   "category": "bananas",
#   "caption": "A cluster of three ripe bananas with a vibrant yellow hue and subtle green tips, illustrated in a flat cartoon vector style with smooth lines and soft shadows, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded., render in the exact same illustration style and details as described: A cluster of three ripe bananas with a vibrant yellow hue and subtle green tips, illustrated in a flat cartoon vector style with smooth lines and soft shadows, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-GHmW9gv8AMu9DmgcO0xPC3S0.png?st=2025-06-09T06%3A29%3A12Z&se=2025-06-09T08%3A29%3A12Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T01%3A35%3A56Z&ske=2025-06-10T01%3A35%3A56Z&sks=b&skv=2024-08-04&sig=mRhw04NTAGbTA96aNJhsLmgYwjnxI4838EtC5SVou50%3D
# Saved generated image to outputs/base_prompt/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded_generated.png
# Processing: test_images/05_Black_currant.png
# Caption output: {
#   "category": "blackcurrants",
#   "caption": "A cluster of glossy blackcurrants with a rich, deep purple hue, nestled among vibrant green leaves, illustrated in a playful cartoon style with soft shading and no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant., render in the exact same illustration style and details as described: A cluster of glossy blackcurrants with a rich, deep purple hue, nestled among vibrant green leaves, illustrated in a playful cartoon style with soft shading and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-m7Ipo9eBmyidNxYXyAClM5O9.png?st=2025-06-09T06%3A29%3A35Z&se=2025-06-09T08%3A29%3A35Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T10%3A09%3A24Z&ske=2025-06-09T10%3A09%3A24Z&sks=b&skv=2024-08-04&sig=mZKbIsRCazWHnvyyNUXXbbpAYPdyhijh6TtcUY6gnHQ%3D
# Saved generated image to outputs/base_prompt/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant_generated.png
# Processing: test_images/15_Grapes.png
# Caption output: {
#   "category": "grapes",
#   "caption": "A cluster of plump, dark purple grapes with a glossy finish, featuring vibrant green leaves and a twisting vine, illustrated in a colorful flat vector cartoon style with no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded., render in the exact same illustration style and details as described: A cluster of plump, dark purple grapes with a glossy finish, featuring vibrant green leaves and a twisting vine, illustrated in a colorful flat vector cartoon style with no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-OxQSIer4KS7hC0qvAKQFS8qM.png?st=2025-06-09T06%3A29%3A57Z&se=2025-06-09T08%3A29%3A57Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T04%3A36%3A00Z&ske=2025-06-10T04%3A36%3A00Z&sks=b&skv=2024-08-04&sig=c2brWpI/z1vaUXsNyM8nea3fI8npmqDFrw9ClT2hvXw%3D
# Saved generated image to outputs/base_prompt/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded_generated.png
# Processing: test_images/30_Salmon.png
# Caption output: {
#   "category": "fish",
#   "caption": "A detailed illustration of a silver fish with a streamlined body, featuring dark blue fins and a speckled pattern along its sides, in a flat cartoon vector style, with soft lighting and no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines., render in the exact same illustration style and details as described: A detailed illustration of a silver fish with a streamlined body, featuring dark blue fins and a speckled pattern along its sides, in a flat cartoon vector style, with soft lighting and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-FNT1mIzUfvF17hXNF4YvoZ49.png?st=2025-06-09T06%3A30%3A22Z&se=2025-06-09T08%3A30%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T14%3A00%3A41Z&ske=2025-06-09T14%3A00%3A41Z&sks=b&skv=2024-08-04&sig=ARJO03qw8WLOMyQh5wZ7TkUu5J/agIglJKhbZH3xqpM%3D
# Saved generated image to outputs/base_prompt/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines_generated.png
# Processing: test_images/35_Catfish.png
# Caption output: {
#   "category": "catfish",
#   "caption": "A stylized catfish with a smooth, elongated body in shades of orange and brown, featuring prominent whiskers and detailed fins, illustrated in a flat cartoon vector style with soft lighting and no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines., render in the exact same illustration style and details as described: A stylized catfish with a smooth, elongated body in shades of orange and brown, featuring prominent whiskers and detailed fins, illustrated in a flat cartoon vector style with soft lighting and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-vedSGF2aUS5K46o4bh5xygbc.png?st=2025-06-09T06%3A30%3A45Z&se=2025-06-09T08%3A30%3A45Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T02%3A30%3A55Z&ske=2025-06-10T02%3A30%3A55Z&sks=b&skv=2024-08-04&sig=fsfQYLNhI7zO2gHP5PqUQje/1qTIkSsZj8rB7szE5vM%3D
# Saved generated image to outputs/base_prompt/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines_generated.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: {
#   "category": "lemon",
#   "caption": "A vibrant yellow lemon slice with a glossy surface and visible juice droplets, featuring a detailed pattern of segments and a bright white rind, in a flat cartoon vector style with soft shadows and no background.",
#   "image_path": "<actual image path>",
#   "prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style., render in the exact same illustration style and details as described: A vibrant yellow lemon slice with a glossy surface and visible juice droplets, featuring a detailed pattern of segments and a bright white rind, in a flat cartoon vector style with soft shadows and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-tk20s88TQbbH0pQlbGPjPuvy.png?st=2025-06-09T06%3A31%3A08Z&se=2025-06-09T08%3A31%3A08Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T22%3A40%3A13Z&ske=2025-06-09T22%3A40%3A13Z&sks=b&skv=2024-08-04&sig=ooSACDej73orzex9KRy6MfYJrZvpywPPnbZHr6FYoBI%3D
# Saved generated image to outputs/base_prompt/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style_generated.png
#
# --- ALL DONE ---

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base (Enhanced)
#
# **User Input:**
#
# The user uploads an image and provides a prompt describing what changes should be made to the image.
#
# **Step 1 — Caption Generation and Visual Analysis (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the GPT-4o-mini model.
# + GPT-4o-mini analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + Additionally, it extracts key visual features including:
#     + Background description (e.g., plain, textured, outdoor, indoor, no background),
#     + Style details (e.g., flat vector, watercolor, cartoonish, realistic),
#     + Quantity, number of objects visible in the image.
#
# All these extracted details (caption, background, drawing_style, quantity) are structured and returned together.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the full set of extracted **visual features (caption, background, drawing_style, quantity)** are merged into a comprehensive final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
#
# DALL·E 3 generates a new image that preserves the style and visual composition of the original while incorporating the user’s requested modifications and respecting the extracted background, style, and quantity information.
#
# **Output:**
#
# + A newly generated image that reflects the original style, background, quantity, and the desired changes from the prompt.
# + The output is saved and logged along with the image paths, generated caption, and all extracted visual features.

# %%
API_KEY= "your_api_key"

# Initialize the OpenAI client
client = OpenAI(api_key=API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template = """
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt describing how it should be redesigned.

Task:
Generate a JSON object that contains:
- "category": the general type of food shown (like apple, tomato, etc.)
- "caption": Generate a **detailed caption** describing the image. A fluent, descriptive sentence describing the image, including color, drawing style, lighting, quantity, and background.These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.
- "drawing_style": a short phrase describing the illustration style (e.g., flat cartoon vector, watercolor, realistic, 3D render, line art, etc.)
- "quantity": an integer described in the user prompt.
- "background": describe if the background is visible, or say "no background".


Output caption example:
"A red "category" and a sliced "category" with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three "category" with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "category": "<detected food category>",
  "caption": "<a descriptive sentence for DALL·E>",
  "drawing_style": "<short phrase>",
  "quantity": <integer>,
  "background": "<description or 'no background'>",
  "image_path": "<actual image path>",
  "user_prompt": "<user prompt>",
  "generated_image_path": "<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")

    formatted_prompt = prompt_template.format(user_prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        # Parsed necessary information
        caption = parsed["caption"]         
        dalle_prompt = user_prompt 
        quantity = parsed["quantity"]
        drawing_style = parsed["drawing_style"]
        background = parsed["background"]


        # Create a full prompt for DALL·E using the caption,quantity,drawing_style  and user instruction.
        full_prompt = (
            f"{dalle_prompt}. Strictly draw {quantity} "
            f"in {drawing_style} style. Ensure all of them follow this description: {caption}."
        )

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)

        # saved the generated images
        os.makedirs("outputs/base_prompt_improved", exist_ok=True)
        generated_image_path = f"outputs/base_prompt_improved/{safe_prompt}_generated.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path
        parsed["user_prompt"] = user_prompt


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")

# saved the json file
with open("outputs/base_prompt_improved/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: ```json
# {
#   "category": "apple",
#   "caption": "A shiny red apple with a vibrant green leaf beside a freshly sliced apple revealing its juicy white flesh and brown seeds, in a colorful flat cartoon vector style, bright lighting, vivid colors, no background",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 2,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background. Strictly draw 2 in flat cartoon vector style. Ensure all of them follow this description: A shiny red apple with a vibrant green leaf beside a freshly sliced apple revealing its juicy white flesh and brown seeds, in a colorful flat cartoon vector style, bright lighting, vivid colors, no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-7dcxOu21UWL18Pb1AzYYN2vA.png?st=2025-06-09T06%3A48%3A37Z&se=2025-06-09T08%3A48%3A37Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T11%3A46%3A19Z&ske=2025-06-09T11%3A46%3A19Z&sks=b&skv=2024-08-04&sig=0%2Bt%2Bz3XyVMMU6c3fAX2iEccC/c8ZBp36ZCaroJIRuZ8%3D
# Saved generated image to outputs/base_prompt_improved/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background_generated.png
# Processing: test_images/S_02_Apricot.png
# Caption output: ```json
# {
#   "category": "peach",
#   "caption": "A vibrant orange peach with a glossy surface and a small green leaf attached to its stem, illustrated in a flat cartoon vector style, featuring bright colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Create a single peach illustration with a leaf.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant orange peach with a glossy surface and a small green leaf attached to its stem, illustrated in a flat cartoon vector style, featuring bright colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-yoIWyco8AO61xzA0c2kJVit6.png?st=2025-06-09T06%3A49%3A00Z&se=2025-06-09T08%3A49%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T09%3A12%3A22Z&ske=2025-06-09T09%3A12%3A22Z&sks=b&skv=2024-08-04&sig=R1xvGvGxRI1h64ndGSFWqtHm8%2BESyPHEiYxIdru/%2Bsc%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_shiny_red_apple_with_a_vibrant_green_leaf_in_the_same_digital_illustration_style_as_s_02_apricotpng_the_apple_should_be_centered_well-lit_and_have_soft_shadows_like_the_apricot_image_generated.png
# Processing: test_images/S_03_Avocado_1.png
# Caption output: ```json
# {
#   "category": "avocado",
#   "caption": "A vibrant green avocado half with a smooth, creamy yellow interior and a large brown pit, illustrated in a flat cartoon vector style, featuring bright colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Redesign the avocado image to be more colorful and cartoonish.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant green avocado half with a smooth, creamy yellow interior and a large brown pit, illustrated in a flat cartoon vector style, featuring bright colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-lbmjQSqZBfqeyIIURp7aEW1u.png?st=2025-06-09T06%3A49%3A22Z&se=2025-06-09T08%3A49%3A22Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T22%3A15%3A56Z&ske=2025-06-09T22%3A15%3A56Z&sks=b&skv=2024-08-04&sig=FFu5mJ5vcHtWPpM/otYxPcsRaGjjJRbES7gayEXEjYQ%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look_generated.png
# Processing: test_images/04_Banana.png
# Caption output: ```json
# {
#   "category": "banana",
#   "caption": "A bunch of three ripe bananas with a vibrant yellow color and slight green tips, illustrated in a flat cartoon vector style, featuring soft lighting and bright colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 3,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.. Strictly draw 3 in flat cartoon vector style. Ensure all of them follow this description: A bunch of three ripe bananas with a vibrant yellow color and slight green tips, illustrated in a flat cartoon vector style, featuring soft lighting and bright colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-n5wF9vMjax3EmJlWbME1Dj2A.png?st=2025-06-09T06%3A49%3A46Z&se=2025-06-09T08%3A49%3A46Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T17%3A56%3A20Z&ske=2025-06-09T17%3A56%3A20Z&sks=b&skv=2024-08-04&sig=s0nuG67h52qm%2BXSRuPTWJJCxLlfyoq1vAEnf1lpngxY%3D
# Saved generated image to outputs/base_prompt_improved/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded_generated.png
# Processing: test_images/05_Black_currant.png
# Caption output: ```json
# {
#   "category": "blackcurrant",
#   "caption": "A cluster of shiny blackcurrants with a few leaves, depicted in a vibrant flat cartoon vector style, featuring bright colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A cluster of shiny blackcurrants with a few leaves, depicted in a vibrant flat cartoon vector style, featuring bright colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-vruFqXwLGc0JEK2tuJFuy7UE.png?st=2025-06-09T06%3A50%3A06Z&se=2025-06-09T08%3A50%3A06Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T07%3A50%3A06Z&ske=2025-06-10T07%3A50%3A06Z&sks=b&skv=2024-08-04&sig=r/CIyQgs0AAKZqsZNEeVNapZ2%2BmHS1duRuFctZNghsg%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant_generated.png
# Processing: test_images/15_Grapes.png
# Caption output: ```json
# {
#   "category": "grapes",
#   "caption": "A cluster of plump, dark purple grapes with a glossy finish, accompanied by vibrant green leaves, illustrated in a colorful flat cartoon vector style, bright lighting, vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Create a colorful illustration of grapes.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A cluster of plump, dark purple grapes with a glossy finish, accompanied by vibrant green leaves, illustrated in a colorful flat cartoon vector style, bright lighting, vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-PfGR42v1Z4BPrRlfFcSqky5S.png?st=2025-06-09T06%3A50%3A29Z&se=2025-06-09T08%3A50%3A29Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T08%3A55%3A11Z&ske=2025-06-09T08%3A55%3A11Z&sks=b&skv=2024-08-04&sig=OHXICNiaoGYLVgwm5Q1D41wLOYkeWsyU0DY%2BYD8gEnA%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded_generated.png
# Processing: test_images/30_Salmon.png
# Caption output: ```json
# {
#   "category": "fish",
#   "caption": "A detailed illustration of a silver fish with a sleek body and dark blue fins, showcasing its shimmering scales under soft lighting, in a flat cartoon vector style, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Create a cartoon-style illustration of a fish.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A detailed illustration of a silver fish with a sleek body and dark blue fins, showcasing its shimmering scales under soft lighting, in a flat cartoon vector style, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-1xAeGIfUyPwAqyf4cLhp8CHH.png?st=2025-06-09T06%3A50%3A51Z&se=2025-06-09T08%3A50%3A51Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T14%3A26%3A30Z&ske=2025-06-09T14%3A26%3A30Z&sks=b&skv=2024-08-04&sig=EXE3K7t0Dqfb36AP0gBWKK33nTXVPi4vWLKGN0HnLJY%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines_generated.png
# Processing: test_images/35_Catfish.png
# Caption output: ```json
# {
#   "category": "catfish",
#   "caption": "A vibrant orange catfish with detailed fins and whiskers, illustrated in a flat cartoon vector style, featuring soft lighting and bright colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Create a colorful illustration of a catfish.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant orange catfish with detailed fins and whiskers, illustrated in a flat cartoon vector style, featuring soft lighting and bright colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-LeG4A3BKsLRAthSQTY1uZtic.png?st=2025-06-09T06%3A51%3A15Z&se=2025-06-09T08%3A51%3A15Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T05%3A23%3A35Z&ske=2025-06-10T05%3A23%3A35Z&sks=b&skv=2024-08-04&sig=WJvbqof20kDOlvs%2Bx2R8vaxY0V25Lt2%2Bvyp2R/ra0Rk%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines_generated.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: ```json
# {
#   "category": "lemon",
#   "caption": "A vibrant yellow lemon slice with visible juice droplets and a glossy surface, illustrated in a flat cartoon vector style, bright lighting, vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "<user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant yellow lemon slice with visible juice droplets and a glossy surface, illustrated in a flat cartoon vector style, bright lighting, vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-T0sK6Rb4qhuSsIMnm9K6bfNd.png?st=2025-06-09T06%3A51%3A39Z&se=2025-06-09T08%3A51%3A39Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T12%3A02%3A50Z&ske=2025-06-09T12%3A02%3A50Z&sks=b&skv=2024-08-04&sig=n82dzF6MR/LHCn5YWSo45swGwTtyNV3pQuz%2BfPEWiRo%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style_generated.png
#
# --- ALL DONE ---
