# %%
import os
import base64
import json
import re
import time
import requests
from openai import OpenAI
from PIL import Image
from io import BytesIO
from config import OPENAI_API_KEY

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base
# **User Input:**
#
# + The user uploads an **image** and provides a **prompt** describing what changes should be made to the image.
#
# **Step 1 — Caption Generation (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the **GPT-4o-mini** model.
# + *GPT-4o-mini* analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + This caption includes visual attributes such as colors, drawing style, food category, background, and layout.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the generated caption are merged into a final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
# + DALL·E 3 generates a new image that preserves the style of the original but incorporates the requested modifications.
#
# **Output:**
#
# + A newly generated image that reflects both the original style and the desired changes from the prompt.
# + The output is saved and logged along with the image paths and generated caption.

# %%
# Initialize the OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template = """
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt describing how it should be redesigned.

Task:
Generate a **detailed caption** describing the image. The caption should:
- Include visual details like color, pattern, drawing style, background if visible.
- Analyze the "category"(the general type of food depicted) and describe its key features.
- Be a single sentence, fluent, and descriptive.
- These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.

Output caption example:
"A red "category" and a sliced "category" with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three "category" with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "category": "<your generated food category here>",
  "caption": "<your generated caption here>",
  "image_path": "<actual image path>",
  "user_prompt": "<actual user prompt>",
  "generated_image_path":"<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    # Read and encode image as base64
    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")
    
    # Format the prompt for GPT
    formatted_prompt = prompt_template.format(user_prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        caption = parsed["caption"]         
        dalle_prompt = user_prompt 
        
        # Create a full prompt for DALL·E using both the caption and user instruction.
        full_prompt = f"{dalle_prompt}, render in the exact same illustration style and details as described: {caption}"

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # Wait to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)
        
        # Download and save the generated image
        os.makedirs("outputs/base_prompt", exist_ok=True)
        generated_image_path = f"outputs/base_prompt/{safe_prompt}_generated.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")
# Save all results to a JSON file
with open("outputs/base_prompt/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: {
#   "category": "apple",
#   "caption": "A shiny red apple with a vibrant green leaf beside a freshly sliced half revealing its creamy white flesh and small brown seeds, illustrated in a flat cartoon vector style with soft lighting and no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background, render in the exact same illustration style and details as described: A shiny red apple with a vibrant green leaf beside a freshly sliced half revealing its creamy white flesh and small brown seeds, illustrated in a flat cartoon vector style with soft lighting and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-OLpx2Ze6MxW9HKEiO4whHPeg.png?st=2025-06-09T11%3A59%3A39Z&se=2025-06-09T13%3A59%3A39Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T01%3A15%3A54Z&ske=2025-06-10T01%3A15%3A54Z&sks=b&skv=2024-08-04&sig=ptzwjgyChP59WDo/%2BIi/R0ATGKAC8CKyS/Cf5TZgidg%3D
# Saved generated image to outputs/base_prompt/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background_generated.png
# Processing: test_images/S_02_Apricot.png
# Caption output: {
#   "category": "peach",
#   "caption": "A vibrant orange peach with a glossy surface and a small green leaf attached to its stem, illustrated in a smooth, flat cartoon vector style, against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image., render in the exact same illustration style and details as described: A vibrant orange peach with a glossy surface and a small green leaf attached to its stem, illustrated in a smooth, flat cartoon vector style, against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-auLByPltm7YvreFhc84sUIj2.png?st=2025-06-09T12%3A00%3A04Z&se=2025-06-09T14%3A00%3A04Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T01%3A02%3A01Z&ske=2025-06-10T01%3A02%3A01Z&sks=b&skv=2024-08-04&sig=lHQTvT4QaJo4ttXS23LdXvlWh%2BDh5XS%2BobtJNSheYE4%3D
# Saved generated image to outputs/base_prompt/draw_a_shiny_red_apple_with_a_vibrant_green_leaf_in_the_same_digital_illustration_style_as_s_02_apricotpng_the_apple_should_be_centered_well-lit_and_have_soft_shadows_like_the_apricot_image_generated.png
# Processing: test_images/S_03_Avocado_1.png
# Caption output: {
#   "category": "avocado",
#   "caption": "A vibrant green avocado half with a smooth, creamy yellow interior and a round brown pit, illustrated in a flat cartoon vector style with bold outlines and bright colors, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look., render in the exact same illustration style and details as described: A vibrant green avocado half with a smooth, creamy yellow interior and a round brown pit, illustrated in a flat cartoon vector style with bold outlines and bright colors, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-66wH6lwfXZwEWpzcao8LRAOm.png?st=2025-06-09T12%3A00%3A29Z&se=2025-06-09T14%3A00%3A29Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T10%3A45%3A44Z&ske=2025-06-10T10%3A45%3A44Z&sks=b&skv=2024-08-04&sig=smOg9hSGHGdEZeC0zIRF3uvrOUhFzNqndfnGHwD4Gb4%3D
# Saved generated image to outputs/base_prompt/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look_generated.png
# Processing: test_images/04_Banana.png
# Caption output: {
#   "category": "banana",
#   "caption": "A cluster of three ripe bananas with a vibrant yellow hue and subtle green tips, illustrated in a smooth, flat cartoon vector style with soft shadows, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded., render in the exact same illustration style and details as described: A cluster of three ripe bananas with a vibrant yellow hue and subtle green tips, illustrated in a smooth, flat cartoon vector style with soft shadows, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-qB6Yu1AgYDLfG03dZtf2sUzb.png?st=2025-06-09T12%3A00%3A55Z&se=2025-06-09T14%3A00%3A55Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T07%3A24%3A10Z&ske=2025-06-10T07%3A24%3A10Z&sks=b&skv=2024-08-04&sig=lZ0/TgQHnAm3y8w8Z8OaZK%2BQ7xWGFXYm1Hq157gCCw4%3D
# Saved generated image to outputs/base_prompt/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded_generated.png
# Processing: test_images/05_Black_currant.png
# Caption output: {
#   "category": "blackcurrants",
#   "caption": "A cluster of glossy blackcurrants with a rich, deep purple-black hue, nestled among vibrant green leaves, illustrated in a playful cartoon style with soft shading and no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant., render in the exact same illustration style and details as described: A cluster of glossy blackcurrants with a rich, deep purple-black hue, nestled among vibrant green leaves, illustrated in a playful cartoon style with soft shading and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-cuMQlSIWRWcLxf3AS2mwULrs.png?st=2025-06-09T12%3A01%3A18Z&se=2025-06-09T14%3A01%3A18Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T08%3A56%3A17Z&ske=2025-06-10T08%3A56%3A17Z&sks=b&skv=2024-08-04&sig=dEpTTmWPU9MzVXrgsvun%2BDEY2c7CUS1QSmzjRu4E6Cw%3D
# Saved generated image to outputs/base_prompt/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant_generated.png
# Processing: test_images/15_Grapes.png
# Caption output: {
#   "category": "grapes",
#   "caption": "A cluster of plump, dark purple grapes with a glossy finish and a few vibrant green leaves, illustrated in a colorful flat vector cartoon style, with no background.",
#   "image_path": "path/to/image.png",
#   "user_prompt": "Create a vibrant cartoon-style illustration of grapes.",
#   "generated_image_path": "path/to/generated_image.png"
# }
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded., render in the exact same illustration style and details as described: A cluster of plump, dark purple grapes with a glossy finish and a few vibrant green leaves, illustrated in a colorful flat vector cartoon style, with no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-kMBosiBDjXKmIPoGQ23rVBp8.png?st=2025-06-09T12%3A01%3A41Z&se=2025-06-09T14%3A01%3A41Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T10%3A21%3A22Z&ske=2025-06-10T10%3A21%3A22Z&sks=b&skv=2024-08-04&sig=zUvzdfheqbo8eJpn2j93kKO9n8s5H1l0d6ZhEZbIHq0%3D
# Saved generated image to outputs/base_prompt/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded_generated.png
# Processing: test_images/30_Salmon.png
# Caption output: {
#   "category": "fish",
#   "caption": "A detailed illustration of a silver fish with a streamlined body, featuring dark blue fins and a speckled pattern along its sides, depicted in a flat cartoon vector style with soft shading and no background.",
#   "image_path": "path/to/image.png",
#   "user_prompt": "Create a cartoon-style fish illustration.",
#   "generated_image_path": "path/to/generated_image.png"
# }
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines., render in the exact same illustration style and details as described: A detailed illustration of a silver fish with a streamlined body, featuring dark blue fins and a speckled pattern along its sides, depicted in a flat cartoon vector style with soft shading and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-dzxKkYIhZxF0n0NfR3TSVw2k.png?st=2025-06-09T12%3A02%3A04Z&se=2025-06-09T14%3A02%3A04Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T01%3A39%3A07Z&ske=2025-06-10T01%3A39%3A07Z&sks=b&skv=2024-08-04&sig=UIJ0QTf3/%2BE7TlfIth4cRIv0NcGIImx0vI%2BOkJxwy08%3D
# Saved generated image to outputs/base_prompt/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines_generated.png
# Processing: test_images/35_Catfish.png
# Caption output: {
#   "category": "catfish",
#   "caption": "A stylized catfish with a smooth, elongated body in shades of orange and brown, featuring prominent whiskers and detailed fins, illustrated in a flat cartoon vector style with no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines., render in the exact same illustration style and details as described: A stylized catfish with a smooth, elongated body in shades of orange and brown, featuring prominent whiskers and detailed fins, illustrated in a flat cartoon vector style with no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-3UYGGlTtEI41Gvb0d07PZLy6.png?st=2025-06-09T12%3A02%3A26Z&se=2025-06-09T14%3A02%3A26Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T23%3A23%3A25Z&ske=2025-06-09T23%3A23%3A25Z&sks=b&skv=2024-08-04&sig=ZW2cmT/mMSLd8o9c9sWnqZ9dCpCiNpHO8yX/wZtbtG8%3D
# Saved generated image to outputs/base_prompt/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines_generated.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: {
#   "category": "lemon",
#   "caption": "A vibrant yellow lemon slice with a glossy surface and visible juice droplets, featuring a bright white rind and detailed segments, in a flat cartoon vector style, soft lighting, vivid colors, no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style., render in the exact same illustration style and details as described: A vibrant yellow lemon slice with a glossy surface and visible juice droplets, featuring a bright white rind and detailed segments, in a flat cartoon vector style, soft lighting, vivid colors, no background
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-Ce0TcZq4gKrZuhOLBrAjYTzY.png?st=2025-06-09T12%3A02%3A49Z&se=2025-06-09T14%3A02%3A49Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T09%3A04%3A56Z&ske=2025-06-10T09%3A04%3A56Z&sks=b&skv=2024-08-04&sig=N1uy%2BwZK2xAHCAwgSqBKZaoQeiZtNyuhQF1U3Lkmd%2BE%3D
# Saved generated image to outputs/base_prompt/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style_generated.png
# Processing: test_images/S_05_Black currant_3.png
# Caption output: {
#   "category": "black olive",
#   "caption": "A glossy black olive with a small brown blemish, depicted in a smooth cartoon vector style, featuring soft lighting and rich, dark colors, with no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "<actual user prompt>",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: This is a  black currant . Draw me a green pear. Use the same image drawing style in the image., render in the exact same illustration style and details as described: A glossy black olive with a small brown blemish, depicted in a smooth cartoon vector style, featuring soft lighting and rich, dark colors, with no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-ZokFDEstDCHU5mPrlGdWyVBV.png?st=2025-06-09T12%3A03%3A12Z&se=2025-06-09T14%3A03%3A12Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T22%3A39%3A31Z&ske=2025-06-09T22%3A39%3A31Z&sks=b&skv=2024-08-04&sig=923h36ZiO6s6E1nuj4E1DMU%2BQKp1NZlmX1TKkrv9eZE%3D
# Saved generated image to outputs/base_prompt/this_is_a_black_currant_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image_generated.png
# Processing: test_images/S_11_Cranbverry_1.png
# Caption output: {
#   "category": "cherry",
#   "caption": "A vibrant red cherry with a glossy surface and a small dark pit, depicted in a flat cartoon vector style with soft shadows, vivid colors, and no background.",
#   "image_path": "path/to/image.png",
#   "user_prompt": "Generate a detailed caption for a cherry image.",
#   "generated_image_path": "path/to/generated_image.png"
# }
# Generating new image from combined prompt: This is a  cranberry . Draw me a green pear. Use the same image drawing style in the image., render in the exact same illustration style and details as described: A vibrant red cherry with a glossy surface and a small dark pit, depicted in a flat cartoon vector style with soft shadows, vivid colors, and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-gAQVyY9zNS0OUVOuPaumjbYs.png?st=2025-06-09T12%3A03%3A34Z&se=2025-06-09T14%3A03%3A34Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T22%3A32%3A34Z&ske=2025-06-09T22%3A32%3A34Z&sks=b&skv=2024-08-04&sig=Xxj7bDPtPzuZDl2oVTAz6/pMLpM%2BSAIoMhlLfETbwXM%3D
# Saved generated image to outputs/base_prompt/this_is_a_cranberry_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image_generated.png
#
# --- ALL DONE ---

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base (Enhanced)
#
# **User Input:**
#
# The user uploads an image and provides a prompt describing what changes should be made to the image.
#
# **Step 1 — Caption Generation and Visual Analysis (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the GPT-4o-mini model.
# + GPT-4o-mini analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + Additionally, it extracts key visual features including:
#     + Background description (e.g., plain, textured, outdoor, indoor, no background),
#     + Style details (e.g., flat vector, watercolor, cartoonish, realistic),
#     + Quantity, number of objects visible in the image.
#
# All these extracted details (caption, background, drawing_style, quantity) are structured and returned together.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the full set of extracted **visual features (caption, background, drawing_style, quantity)** are merged into a comprehensive final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
#
# DALL·E 3 generates a new image that preserves the style and visual composition of the original while incorporating the user’s requested modifications and respecting the extracted background, style, and quantity information.
#
# **Output:**
#
# + A newly generated image that reflects the original style, background, quantity, and the desired changes from the prompt.
# + The output is saved and logged along with the image paths, generated caption, and all extracted visual features.

# %%
# Initialize the OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template ="""
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt{prompt} describing how it should be redesigned.

🔹 Important:
Always prioritize the user's input when generating the caption. If the user mentions a category, style, quantity, or any specific detail, **you must strictly follow the user's input**. User instructions take precedence over visual content.

Your Task as follow:

When generating caption first, you MUST take the user prompt into account. If the user input mentions a category, the category specified by the user should take precedence.
Generate a JSON object that contains:
- "caption": Generate a **detailed caption** describing the image. A fluent, descriptive sentence describing the image, including color, drawing style, lighting, quantity, and background.These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.
- "drawing_style": a short phrase describing the illustration style (e.g., flat cartoon vector, watercolor, realistic, 3D render, line art, etc.)
- "quantity": an integer described in the user prompt.
- "background": describe if the background is visible, or say "no background".
After generating the initial caption, you MUST check if the category inferred from the image differs from the category mentioned in the user prompt.
If there is a conflict, revise the caption to match the category provided by the user. The user's specified category should override your prediction.

Output caption example:
"A red apple and a sliced apple with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three cashew apple with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "caption": "<a descriptive sentence for DALL·E>",
  "drawing_style": "<short phrase>",
  "quantity": <integer>,
  "background": "<description or 'no background'>",
  "image_path": "<actual image path>",
  "user_prompt": "<actual prompt>",
  "generated_image_path": "<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")

    formatted_prompt = prompt_template.format(prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        # Parsed necessary information
        caption = parsed["caption"]         
        dalle_prompt = user_prompt 
        quantity = parsed["quantity"]
        drawing_style = parsed["drawing_style"]
        background = parsed["background"]


        # Create a full prompt for DALL·E using the caption,quantity,drawing_style  and user instruction.
        full_prompt = (
            f"{dalle_prompt}. Strictly draw {quantity} "
            f"in {drawing_style} style. Ensure all of them follow this description: {caption}."
        )

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)

        # saved the generated images
        os.makedirs("outputs/base_prompt_improved", exist_ok=True)
        generated_image_path = f"outputs/base_prompt_improved/{safe_prompt}_generated.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path
        parsed["user_prompt"] = user_prompt


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")

# saved the json file
with open("outputs/base_prompt_improved/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: {
#   "caption": "A shiny red apple and a sliced apple revealing its seeds, illustrated in flat cartoon vector style with vibrant colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 2,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "A soft red tomato with seeds, in flat cartoon vector style, no background",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background. Strictly draw 2 in flat cartoon vector style. Ensure all of them follow this description: A shiny red apple and a sliced apple revealing its seeds, illustrated in flat cartoon vector style with vibrant colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-HSOFGuqQhfEhbS7DPKCIX4ZF.png?st=2025-06-09T11%3A42%3A53Z&se=2025-06-09T13%3A42%3A53Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T12%3A42%3A53Z&ske=2025-06-10T12%3A42%3A53Z&sks=b&skv=2024-08-04&sig=azwazvKN7eKLXz6R2w9Hd177M7Rz4Ot5LPBTzTY6kYA%3D
# Saved generated image to outputs/base_prompt_improved/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background_generated.png
# Processing: test_images/S_02_Apricot.png
# Caption output: ```json
# {
#   "caption": "A shiny red apple with a vibrant green leaf, centered in the image, well-lit with soft shadows, in the same digital illustration style as 'S_02_Apricot.png', vivid colors, no background.",
#   "drawing_style": "digital illustration",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image.",
#   "generated_image_path": "path/to/generated
# Error processing test_images/S_02_Apricot.png: JSON response not found.
# Processing: test_images/S_03_Avocado_1.png
# Caption output: ```json
# {
#   "caption": "A yellow lemon and a sliced lemon showcasing the bright yellow flesh and zesty texture, illustrated in a flat cartoon vector style, with soft lighting and vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 2,
#   "background": "no background",
#   "image_path": "S_03_Avocado_1.png",
#   "user_prompt": "Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.",
#   "generated_image_path": "generated_lemon_image.png"
# }
# ```
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.. Strictly draw 2 in flat cartoon vector style. Ensure all of them follow this description: A yellow lemon and a sliced lemon showcasing the bright yellow flesh and zesty texture, illustrated in a flat cartoon vector style, with soft lighting and vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-vRu9YTdFJ8ifZAZUsctjCQLB.png?st=2025-06-09T11%3A43%3A24Z&se=2025-06-09T13%3A43%3A24Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T05%3A31%3A24Z&ske=2025-06-10T05%3A31%3A24Z&sks=b&skv=2024-08-04&sig=Ncjq9Bl8Is5tYZEX4f8NzET8z/yrcKFdv3%2BRZmB0K9g%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look_generated.png
# Processing: test_images/04_Banana.png
# Caption output: {
#   "caption": "A bunch of three ripe bananas with a glossy surface, illustrated in a vibrant flat cartoon vector style, featuring bright yellow colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 3,
#   "background": "no background",
#   "image_path": "path/to/banana_image.png",
#   "user_prompt": "Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.",
#   "generated_image_path": "path/to/generated_apricot_image.png"
# }
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.. Strictly draw 3 in flat cartoon vector style. Ensure all of them follow this description: A bunch of three ripe bananas with a glossy surface, illustrated in a vibrant flat cartoon vector style, featuring bright yellow colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-2Sn4svnIj3RtBcBNPBVFhQKb.png?st=2025-06-09T11%3A43%3A49Z&se=2025-06-09T13%3A43%3A49Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-08T21%3A00%3A58Z&ske=2025-06-09T21%3A00%3A58Z&sks=b&skv=2024-08-04&sig=mDwiR5jWl9zl9kToHXah0HfnqgergJCjatm9LdhVMqs%3D
# Saved generated image to outputs/base_prompt_improved/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded_generated.png
# Processing: test_images/05_Black_currant.png
# Caption output: ```json
# {
#   "caption": "A single, large, round black currant with a glossy surface, depicted in a flat cartoon vector style, featuring vibrant colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A single, large, round black currant with a glossy surface, depicted in a flat cartoon vector style, featuring vibrant colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-PG3zOdcqDIyeKB321PCPUEvB.png?st=2025-06-09T11%3A44%3A11Z&se=2025-06-09T13%3A44%3A11Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T12%3A07%3A58Z&ske=2025-06-10T12%3A07%3A58Z&sks=b&skv=2024-08-04&sig=OINHlnrRTUfu5IyEfrwQhlFC0BC5mJVxKmXePTDhsjU%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant_generated.png
# Processing: test_images/15_Grapes.png
# Caption output: {
#   "caption": "A cluster of glossy black currants with a shiny surface, depicted in a vibrant flat cartoon vector style, featuring rich black hues and subtle highlights, with green leaves accentuating the berries, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A cluster of glossy black currants with a shiny surface, depicted in a vibrant flat cartoon vector style, featuring rich black hues and subtle highlights, with green leaves accentuating the berries, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-EGZmMzUkQKi9txgED90uLdRc.png?st=2025-06-09T11%3A44%3A33Z&se=2025-06-09T13%3A44%3A33Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T12%3A44%3A33Z&ske=2025-06-10T12%3A44%3A33Z&sks=b&skv=2024-08-04&sig=6%2BXFJGgWD3SHsLzcw8WK%2BgfM5GYmggoDH6%2BhDnfRdLM%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded_generated.png
# Processing: test_images/30_Salmon.png
# Caption output: ```json
# {
#   "caption": "A sliced salmon fillet showcasing vibrant pink flesh with a glossy sheen, in flat cartoon vector style, soft lighting, vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A sliced salmon fillet showcasing vibrant pink flesh with a glossy sheen, in flat cartoon vector style, soft lighting, vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-PdyI6YlaJBM1erjcp5kurjrP.png?st=2025-06-09T11%3A44%3A58Z&se=2025-06-09T13%3A44%3A58Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T12%3A44%3A58Z&ske=2025-06-10T12%3A44%3A58Z&sks=b&skv=2024-08-04&sig=OOsc/THTd32Qg/gY9mDHvhTXGaEi6SX1rocHHz2vRtI%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines_generated.png
# Processing: test_images/35_Catfish.png
# Caption output: ```json
# {
#   "caption": "A salmon illustrated in the same style as the catfish image, featuring vibrant shades of pink and orange with smooth vector lines and soft shading, showcasing its sleek body and distinctive fins, against a clean white background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "35_Catfish.png",
#   "user_prompt": "Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.",
#   "generated_image_path": "generated_salmon_image.png"
# }
# ```
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A salmon illustrated in the same style as the catfish image, featuring vibrant shades of pink and orange with smooth vector lines and soft shading, showcasing its sleek body and distinctive fins, against a clean white background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-szoDpeLcaJXpvK80PUV3C16K.png?st=2025-06-09T11%3A45%3A24Z&se=2025-06-09T13%3A45%3A24Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T05%3A23%3A35Z&ske=2025-06-10T05%3A23%3A35Z&sks=b&skv=2024-08-04&sig=HHGevonBSSCwGL3mi5/pg8wspXPE5IVDRobedJgs2/Q%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines_generated.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: {
#   "caption": "A vibrant green sliced avocado with a smooth surface, illustrated in the same flat cartoon vector style as the orange slice, featuring soft lighting and vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "S_30_Orange_1.png",
#   "user_prompt": "Using the same illustration style as the orange slice image I uploaded, draw a vibrant green sliced avocado with a smooth surface.",
#   "generated_image_path": "S_31_Avocado_1.png"
# }
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant green sliced avocado with a smooth surface, illustrated in the same flat cartoon vector style as the orange slice, featuring soft lighting and vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-7Tr6SYOSQt7dJPxxwQObfqyf.png?st=2025-06-09T11%3A45%3A50Z&se=2025-06-09T13%3A45%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T12%3A45%3A50Z&ske=2025-06-10T12%3A45%3A50Z&sks=b&skv=2024-08-04&sig=UANLbFg9%2BTsh5iVirTLxk44KrBHfGr1pKjU5CDaWnZg%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style_generated.png
# Processing: test_images/S_05_Black currant_3.png
# Caption output: ```json
# {
#   "caption": "A green pear with a smooth skin and a slightly curved shape, illustrated in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/black_currant_image.png",
#   "user_prompt": "This is a black currant. Draw me a green pear. Use the same image drawing style in the image.",
#   "generated_image_path": "path/to/generated_green_pear_image.png"
# }
# ```
# Generating new image from combined prompt: This is a  black currant . Draw me a green pear. Use the same image drawing style in the image.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A green pear with a smooth skin and a slightly curved shape, illustrated in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-l2jwGyDsHsiSNYVA6xxS3kgL.png?st=2025-06-09T11%3A46%3A28Z&se=2025-06-09T13%3A46%3A28Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T10%3A18%3A01Z&ske=2025-06-10T10%3A18%3A01Z&sks=b&skv=2024-08-04&sig=eX7FyEdA%2B150CGeOCaDjNeArKoaIMpeH3dwCdzYxWrw%3D
# Saved generated image to outputs/base_prompt_improved/this_is_a_black_currant_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image_generated.png
# Processing: test_images/S_11_Cranbverry_1.png
# Caption output: ```json
# {
#   "caption": "A green pear with a smooth, glossy surface, depicted in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "This is a cranberry. Draw me a green pear.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: This is a  cranberry . Draw me a green pear. Use the same image drawing style in the image.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A green pear with a smooth, glossy surface, depicted in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-HfknqrCcU0rmRQkdF8JIzQEc.png?st=2025-06-09T11%3A46%3A51Z&se=2025-06-09T13%3A46%3A51Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T02%3A52%3A36Z&ske=2025-06-10T02%3A52%3A36Z&sks=b&skv=2024-08-04&sig=BPhx4EjjwyM8ZMZ5r9ClSeETXWOnwSMJ/y5j13Esz7g%3D
# Saved generated image to outputs/base_prompt_improved/this_is_a_cranberry_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image_generated.png
#
# --- ALL DONE ---
