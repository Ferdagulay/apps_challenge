# %%
import os
import base64
import json
import re
import time
import requests
from openai import OpenAI
from PIL import Image
from io import BytesIO
from config import OPENAI_API_KEY

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base
# **User Input:**
#
# + The user uploads an **image** and provides a **prompt** describing what changes should be made to the image.
#
# **Step 1 — Caption Generation (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the **GPT-4o-mini** model.
# + *GPT-4o-mini* analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + This caption includes visual attributes such as colors, drawing style, food category, background, and layout.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the generated caption are merged into a final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
# + DALL·E 3 generates a new image that preserves the style of the original but incorporates the requested modifications.
#
# **Output:**
#
# + A newly generated image that reflects both the original style and the desired changes from the prompt.
# + The output is saved and logged along with the image paths and generated caption.

# %%
# Initialize the OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template = """
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt {prompt} describing how it should be redesigned.

Task:
Generate a **detailed caption** describing the image. The caption should:
- Include visual details like color, pattern, drawing style, background if visible.
- Analyze the "category"(the general type of food depicted) and describe its key features.
- Be a single sentence, fluent, and descriptive.
- These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.

Output caption example:
"A red "category" and a sliced "category" with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three "category" with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "category": "<your generated food category here>",
  "caption": "<your generated caption here>",
  "image_path": "<actual image path>",
  "user_prompt": "<actual prompt>",
  "generated_image_path":"<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    # Read and encode image as base64
    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")
    
    # Format the prompt for GPT
    formatted_prompt = prompt_template.format(prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        caption = parsed["caption"]         
        parsed["user_prompt"] = user_prompt
        # Create a full prompt for DALL·E using both the caption and user instruction.
        full_prompt = f"{user_prompt}, render in the exact same illustration style and details as described: {caption}"

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # Wait to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)
        
        # Download and save the generated image
        os.makedirs("outputs/base_prompt", exist_ok=True)
        generated_image_path = f"outputs/base_prompt/{safe_prompt}.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")
# Save all results to a JSON file
with open("outputs/base_prompt/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: {
#   "category": "apple",
#   "caption": "A shiny red apple with a vibrant green leaf and a sliced half revealing its white flesh and brown seeds, in flat cartoon vector style, bright colors, no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "A soft red tomato with seeds, in flat cartoon vector style, no background",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background, render in the exact same illustration style and details as described: A shiny red apple with a vibrant green leaf and a sliced half revealing its white flesh and brown seeds, in flat cartoon vector style, bright colors, no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-gmXmBxfGozeFIa2iWzbcJLQW.png?st=2025-06-10T01%3A48%3A43Z&se=2025-06-10T03%3A48%3A43Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T20%3A05%3A01Z&ske=2025-06-10T20%3A05%3A01Z&sks=b&skv=2024-08-04&sig=wBHuiAmTM8CYhcquSdOV8MVbBvOwaIRPJBO5iDAMav4%3D
# Saved generated image to outputs/base_prompt/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background.png
# Processing: test_images/S_02_Apricot.png
# Caption output: {
#   "category": "apple",
#   "caption": "A shiny red apple with a vibrant green leaf, illustrated in a flat cartoon vector style, featuring soft shadows and bright highlights, centered against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image., render in the exact same illustration style and details as described: A shiny red apple with a vibrant green leaf, illustrated in a flat cartoon vector style, featuring soft shadows and bright highlights, centered against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-hDlXTGTeh5dKUCgMBHjSFnfw.png?st=2025-06-10T01%3A49%3A06Z&se=2025-06-10T03%3A49%3A06Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T06%3A20%3A18Z&ske=2025-06-10T06%3A20%3A18Z&sks=b&skv=2024-08-04&sig=jVHCMiSb3FqLBaeAyAI1tV2UfLKa/NdF6lmV1jKa4Gg%3D
# Saved generated image to outputs/base_prompt/draw_a_shiny_red_apple_with_a_vibrant_green_leaf_in_the_same_digital_illustration_style_as_s_02_apricotpng_the_apple_should_be_centered_well-lit_and_have_soft_shadows_like_the_apricot_image.png
# Processing: test_images/S_03_Avocado_1.png
# Caption output: {
#   "category": "lemon",
#   "caption": "A bright yellow lemon and a sliced lemon revealing its juicy interior, illustrated in a flat cartoon vector style with soft lighting and vivid colors, set against a plain white background.",
#   "image_path": "S_03_Avocado_1.png",
#   "user_prompt": "Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.",
#   "generated_image_path": "generated_lemon_image.png"
# }
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look., render in the exact same illustration style and details as described: A bright yellow lemon and a sliced lemon revealing its juicy interior, illustrated in a flat cartoon vector style with soft lighting and vivid colors, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-3q7rjui7XXxlCv0fu6OpadfN.png?st=2025-06-10T01%3A49%3A30Z&se=2025-06-10T03%3A49%3A30Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T16%3A57%3A36Z&ske=2025-06-10T16%3A57%3A36Z&sks=b&skv=2024-08-04&sig=GtJf06ZPrYlrgBgU7jFES8Q0LhV%2BROv9BmjStY/AHkw%3D
# Saved generated image to outputs/base_prompt/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look.png
# Processing: test_images/04_Banana.png
# Caption output: {
#   "category": "banana",
#   "caption": "A bunch of three ripe bananas with a glossy yellow surface and subtle green accents at the tops, illustrated in a vibrant cartoon vector style with smooth curves and minimal shading, set against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded., render in the exact same illustration style and details as described: A bunch of three ripe bananas with a glossy yellow surface and subtle green accents at the tops, illustrated in a vibrant cartoon vector style with smooth curves and minimal shading, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-cqUu16sxVYmD0U99RgDPKa3o.png?st=2025-06-10T01%3A49%3A52Z&se=2025-06-10T03%3A49%3A52Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T06%3A23%3A31Z&ske=2025-06-10T06%3A23%3A31Z&sks=b&skv=2024-08-04&sig=qB5qXm5Dbdozv%2BP9hP35mQcs6e/lJQqNHHYqK5MXlrY%3D
# Saved generated image to outputs/base_prompt/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded.png
# Processing: test_images/05_Black_currant.png
# Caption output: {
#   "category": "black currant",
#   "caption": "A single, large, round black currant with a glossy, deep purple-black surface, featuring subtle highlights and a small brown stem, set against a clean white background in a vibrant, flat cartoon vector style.",
#   "image_path": "<actual image path>",
#   "user_prompt": "Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant., render in the exact same illustration style and details as described: A single, large, round black currant with a glossy, deep purple-black surface, featuring subtle highlights and a small brown stem, set against a clean white background in a vibrant, flat cartoon vector style.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-aKtYXArMfoaxiBlhx6sBudrn.png?st=2025-06-10T01%3A50%3A16Z&se=2025-06-10T03%3A50%3A16Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T05%3A21%3A09Z&ske=2025-06-10T05%3A21%3A09Z&sks=b&skv=2024-08-04&sig=iap9A8CM%2BQiRqLsjYPuB0Toy5SxFD4VBxgLoEPm6Bqk%3D
# Saved generated image to outputs/base_prompt/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant.png
# Processing: test_images/15_Grapes.png
# Caption output: {
#   "category": "black currants",
#   "caption": "A cluster of glossy black currants with a shiny surface and subtle highlights, featuring small green leaves attached to the stems, illustrated in a vibrant cartoon vector style with bold outlines and no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded., render in the exact same illustration style and details as described: A cluster of glossy black currants with a shiny surface and subtle highlights, featuring small green leaves attached to the stems, illustrated in a vibrant cartoon vector style with bold outlines and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-5haeOgUnIJ3hw7BPmZX3TqU2.png?st=2025-06-10T01%3A50%3A50Z&se=2025-06-10T03%3A50%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T21%3A32%3A17Z&ske=2025-06-10T21%3A32%3A17Z&sks=b&skv=2024-08-04&sig=17tvurrlUR9zJ0ePhxJGFrbSz0ew7XPjEZiPrnwm/UI%3D
# Saved generated image to outputs/base_prompt/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded.png
# Processing: test_images/30_Salmon.png
# Caption output: {
#   "category": "salmon",
#   "caption": "A sliced salmon fillet with a vibrant pink hue and delicate marbling, presented in a flat cartoon vector style with smooth outlines and soft shading, against a plain white background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines., render in the exact same illustration style and details as described: A sliced salmon fillet with a vibrant pink hue and delicate marbling, presented in a flat cartoon vector style with smooth outlines and soft shading, against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-q1gTIJGjU1y1w3eNf7ZCd9fU.png?st=2025-06-10T01%3A51%3A13Z&se=2025-06-10T03%3A51%3A13Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T11%3A01%3A21Z&ske=2025-06-10T11%3A01%3A21Z&sks=b&skv=2024-08-04&sig=aEQ1biv1q9bxYwGH/qFC4IUJv3wYzVr3UUZFmQiMPtI%3D
# Saved generated image to outputs/base_prompt/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines.png
# Processing: test_images/35_Catfish.png
# Caption output: {
#   "category": "salmon",
#   "caption": "A vibrant pink salmon with a sleek body and distinct silver scales, illustrated in a flat cartoon vector style with smooth lines and soft shading, set against a plain white background.",
#   "image_path": "path/to/salmon_image.png",
#   "user_prompt": "Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.",
#   "generated_image_path": "path/to/generated_salmon_image.png"
# }
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines., render in the exact same illustration style and details as described: A vibrant pink salmon with a sleek body and distinct silver scales, illustrated in a flat cartoon vector style with smooth lines and soft shading, set against a plain white background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-jlbSvoOjXuCzvhdj19PN8UCs.png?st=2025-06-10T01%3A51%3A36Z&se=2025-06-10T03%3A51%3A36Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T08%3A28%3A21Z&ske=2025-06-10T08%3A28%3A21Z&sks=b&skv=2024-08-04&sig=fvSBHvpSZshnKRjLwotCqtK22DkMF%2BfPkIu/uZogy7w%3D
# Saved generated image to outputs/base_prompt/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: {
#   "category": "avocado",
#   "caption": "A vibrant green sliced avocado with a smooth surface, showcasing its creamy texture and rich color in a flat cartoon vector style, soft lighting, vivid colors, no background.",
#   "image_path": "S_30_Orange_1.png",
#   "user_prompt": "Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style.",
#   "generated_image_path": "S_31_Avocado_1.png"
# }
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style., render in the exact same illustration style and details as described: A vibrant green sliced avocado with a smooth surface, showcasing its creamy texture and rich color in a flat cartoon vector style, soft lighting, vivid colors, no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-4D5Vh9bOg2639POtEbPFRnqq.png?st=2025-06-10T01%3A51%3A59Z&se=2025-06-10T03%3A51%3A59Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T14%3A21%3A36Z&ske=2025-06-10T14%3A21%3A36Z&sks=b&skv=2024-08-04&sig=tOzZ77xRVVKMUyaOX7c63lvXq8D%2Byd2fgMMALEda7Zc%3D
# Saved generated image to outputs/base_prompt/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style.png
# Processing: test_images/S_05_Black currant_3.png
# Caption output: {
#   "category": "black currant",
#   "caption": "A single glossy black currant with a smooth surface and a small brownish stem, depicted in a flat cartoon vector style with vibrant colors and no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "This is a black currant. Draw me a green pear.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: This is a  black currant . Draw me a green pear. Use the same image drawing style in the image., render in the exact same illustration style and details as described: A single glossy black currant with a smooth surface and a small brownish stem, depicted in a flat cartoon vector style with vibrant colors and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-4Nz3Z36Q6EK5uQPyzD4jErio.png?st=2025-06-10T01%3A52%3A23Z&se=2025-06-10T03%3A52%3A23Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-10T02%3A52%3A23Z&ske=2025-06-11T02%3A52%3A23Z&sks=b&skv=2024-08-04&sig=hczBa/GvvtFP6xymSN0Ds9oDgOFSnUmHW2Wmhirz1jQ%3D
# Saved generated image to outputs/base_prompt/this_is_a_black_currant_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image.png
# Processing: test_images/S_11_Cranbverry_1.png
# Caption output: {
#   "category": "cranberry",
#   "caption": "A vibrant red cranberry with a glossy surface and subtle highlights, featuring a small dark indentation, in a flat cartoon vector style with soft lighting and no background.",
#   "image_path": "<actual image path>",
#   "user_prompt": "This is a cranberry. Draw me a green pear.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: This is a  cranberry . Draw me a green pear. Use the same image drawing style in the image., render in the exact same illustration style and details as described: A vibrant red cranberry with a glossy surface and subtle highlights, featuring a small dark indentation, in a flat cartoon vector style with soft lighting and no background.
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-rQ9kH2AtlzM6M0vH8VssPQeT.png?st=2025-06-10T01%3A52%3A48Z&se=2025-06-10T03%3A52%3A48Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-10T02%3A13%3A36Z&ske=2025-06-11T02%3A13%3A36Z&sks=b&skv=2024-08-04&sig=RvSmlvGX830wxjje2YGOHC%2BsAi5hc0Wv%2BriKSLNquF0%3D
# Saved generated image to outputs/base_prompt/this_is_a_cranberry_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image.png
#
# --- ALL DONE ---

# %% [markdown]
# ## GPT-4o-mini + DALL·E 3 Style Transfer Pipeline Base (Enhanced)
#
# **User Input:**
#
# The user uploads an image and provides a prompt describing what changes should be made to the image.
#
# **Step 1 — Caption Generation and Visual Analysis (via GPT-4o-mini):**
#
# + The uploaded image and the user's prompt are sent to the GPT-4o-mini model.
# + GPT-4o-mini analyzes the visual content of the image and generates a detailed, DALL·E-friendly caption.
# + Additionally, it extracts key visual features including:
#     + Background description (e.g., plain, textured, outdoor, indoor, no background),
#     + Style details (e.g., flat vector, watercolor, cartoonish, realistic),
#     + Quantity, number of objects visible in the image.
#
# All these extracted details (caption, background, drawing_style, quantity) are structured and returned together.
#
# **Step 2 — Image Generation (via DALL·E 3):**
#
# + The original user prompt and the full set of extracted **visual features (caption, background, drawing_style, quantity)** are merged into a comprehensive final prompt.
# + This combined prompt is sent to DALL·E 3, along with the original image style as reference.
#
# DALL·E 3 generates a new image that preserves the style and visual composition of the original while incorporating the user’s requested modifications and respecting the extracted background, style, and quantity information.
#
# **Output:**
#
# + A newly generated image that reflects the original style, background, quantity, and the desired changes from the prompt.
# + The output is saved and logged along with the image paths, generated caption, and all extracted visual features.

# %%
# Initialize the OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)
image_extensions = (".jpg", ".jpeg", ".png")
all_results = []

# Prompt template to instruct GPT for image captioning
prompt_template ="""
You are a image captioning assistant helping to generate training captions for a dataset of foods images.
You will receive a food image and a user prompt {prompt} describing how it should be redesigned.

🔹 Important:
Always prioritize the user's input when generating the caption. If the user mentions a category, style, quantity, or any specific detail, **you must strictly follow the user's input**. User instructions take precedence over visual content.

Your Task as follow:

When generating caption first, you MUST take the user prompt into account. If the user input mentions a category, the category specified by the user should take precedence.
Generate a JSON object that contains:
- "caption": Generate a **detailed caption** describing the image. A fluent, descriptive sentence describing the image, including color, drawing style, lighting, quantity, and background.These captions will be used as input for the DALL·E model. Generate captions suitable as prompts for the DALL·E model.
- "drawing_style": a short phrase describing the illustration style (e.g., flat cartoon vector, watercolor, realistic, 3D render, line art, etc.)
- "quantity": an integer described in the user prompt.
- "background": describe if the background is visible, or say "no background".
After generating the initial caption, you MUST check if the category inferred from the image differs from the category mentioned in the user prompt.
If there is a conflict, revise the caption to match the category provided by the user. The user's specified category should override your prediction.

Output caption example:
"A red apple and a sliced apple with seeds, in flat cartoon vector style, soft lighting, vivid colors, no background"
"Three cashew apple with cashew nuts and green leaves on a branch, in colorful flat vector cartoon style, no background"

Use this format:
{{
  "caption": "<a descriptive sentence for DALL·E>",
  "drawing_style": "<short phrase>",
  "quantity": <integer>,
  "background": "<description or 'no background'>",
  "image_path": "<actual image path>",
  "user_prompt": "<actual prompt>",
  "generated_image_path": "<your generated image path>"
}}
"""

def download_and_save_image(image_url: str, save_path: str) -> None:
    """
    Downloads an image from a given URL and saves it to the specified path.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    img.save(save_path)

def output_filename(name: str) -> str:
    """
    Formats a given name into a valid filename.
    """
    name = re.sub(r'[^\w\s-]', '', name)
    name = re.sub(r'\s+', '_', name)
    return name.strip().lower()

# Load the input JSON file containing image paths and user prompts
with open("test_inputs.json", "r", encoding="utf-8") as f:
    prompt_items = json.load(f)

# Iterate through each item (image + user prompt)
for item in prompt_items:
    image_path = item["filename"]
    user_prompt = item["user_prompt"]

    if not image_path.lower().endswith(image_extensions):
        print(f"Skipping {image_path} - unsupported extension")
        continue

    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        continue

    print(f"Processing: {image_path}")

    with open(image_path, "rb") as img_file:
        base64_image = base64.b64encode(img_file.read()).decode("utf-8")

    formatted_prompt = prompt_template.format(prompt=user_prompt, base64_image=base64_image)

    try:
        # Send image and prompt to GPT for caption generation
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": formatted_prompt},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            max_tokens=150,
            temperature=0
        )

        raw_output = response.choices[0].message.content
        print("Caption output:", raw_output)

        json_match = re.search(r'\{.*\}', raw_output, re.DOTALL)
        if not json_match:
            raise ValueError("JSON response not found.")

        parsed = json.loads(json_match.group(0))
        

        # Parsed necessary information
        caption = parsed["caption"]         
        dalle_prompt = user_prompt 
        quantity = parsed["quantity"]
        drawing_style = parsed["drawing_style"]
        background = parsed["background"]


        # Create a full prompt for DALL·E using the caption,quantity,drawing_style  and user instruction.
        full_prompt = (
            f"{dalle_prompt}. Strictly draw {quantity} "
            f"in {drawing_style} style. Ensure all of them follow this description: {caption}."
        )

        # Request DALL·E to generate a new image
        print(f"Generating new image from combined prompt: {full_prompt}")
        dalle_response = client.images.generate(
            model="dall-e-3",
            prompt=full_prompt,
            n=1,
            size="1024x1024"
        )

        # to avoid rate limit issues
        time.sleep(5) 

        generated_image_url = dalle_response.data[0].url
        print(f"Generated image URL: {generated_image_url}")
        safe_prompt = output_filename(user_prompt)

        # saved the generated images
        os.makedirs("outputs/base_prompt_improved", exist_ok=True)
        generated_image_path = f"outputs/base_prompt_improved/{safe_prompt}.png"
        download_and_save_image(generated_image_url, generated_image_path)
        print(f"Saved generated image to {generated_image_path}")

        parsed["generated_image_path"] = generated_image_path
        parsed["image_path"] = image_path
        parsed["user_prompt"] = user_prompt


        all_results.append(parsed)

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        time.sleep(2)

print("\n--- ALL DONE ---")

# saved the json file
with open("outputs/base_prompt_improved/foods_fruit_captions_and_generated.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
# Out:
# Processing: test_images/01_Apple.png
# Caption output: {
#   "caption": "A shiny red apple and a sliced apple revealing its seeds, in flat cartoon vector style, bright colors, soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 2,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "A soft red tomato with seeds, in flat cartoon vector style, no background describing how it should be redesigned.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: A soft red tomato with seeds, in flat cartoon vector style, no background. Strictly draw 2 in flat cartoon vector style. Ensure all of them follow this description: A shiny red apple and a sliced apple revealing its seeds, in flat cartoon vector style, bright colors, soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-hEnMNytnQtbiO1hitL33daZc.png?st=2025-06-10T01%3A42%3A55Z&se=2025-06-10T03%3A42%3A55Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T05%3A06%3A37Z&ske=2025-06-10T05%3A06%3A37Z&sks=b&skv=2024-08-04&sig=gGFsjtcSuMQXwObcsewrVDZ67/7oHvhAo6dHo1Itirg%3D
# Saved generated image to outputs/base_prompt_improved/a_soft_red_tomato_with_seeds_in_flat_cartoon_vector_style_no_background.png
# Processing: test_images/S_02_Apricot.png
# Caption output: ```json
# {
#   "caption": "A shiny red apple with a vibrant green leaf, centered in the image, well-lit with soft shadows, in the same digital illustration style as 'S_02_Apricot.png', vivid colors, no background.",
#   "drawing_style": "digital illustration",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/original/image.png",
#   "user_prompt": "Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'.",
#   "generated_image_path": "path/to/generated/image.png"
# }
# ```
# Generating new image from combined prompt: Draw a shiny red apple with a vibrant green leaf in the same digital illustration style as 'S_02_Apricot.png'. The apple should be centered, well-lit, and have soft shadows like the apricot image.. Strictly draw 1 in digital illustration style. Ensure all of them follow this description: A shiny red apple with a vibrant green leaf, centered in the image, well-lit with soft shadows, in the same digital illustration style as 'S_02_Apricot.png', vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-QFJeZ7Tr6FoBCTF8kzMNmidu.png?st=2025-06-10T01%3A43%3A20Z&se=2025-06-10T03%3A43%3A20Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T22%3A50%3A13Z&ske=2025-06-10T22%3A50%3A13Z&sks=b&skv=2024-08-04&sig=hEjBwQEb9sMSUVzZpXauhn78EtJWRiPbn5nrlQ5sTcw%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_shiny_red_apple_with_a_vibrant_green_leaf_in_the_same_digital_illustration_style_as_s_02_apricotpng_the_apple_should_be_centered_well-lit_and_have_soft_shadows_like_the_apricot_image.png
# Processing: test_images/S_03_Avocado_1.png
# Caption output: ```json
# {
#   "caption": "A yellow lemon and a sliced lemon, both illustrated in a flat cartoon vector style, featuring bright yellow colors and soft lighting, with a clean and vibrant appearance, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 2,
#   "background": "no background",
#   "image_path": "S_03_Avocado_1.png",
#   "user_prompt": "Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.",
#   "generated_image_path": "generated_lemon_image.png"
# }
# ```
# Generating new image from combined prompt: Draw a yellow lemon and a sliced lemon in the same illustration style as the uploaded image (S_03_Avocado_1.png). Match the lighting, colors, and vector look.. Strictly draw 2 in flat cartoon vector style. Ensure all of them follow this description: A yellow lemon and a sliced lemon, both illustrated in a flat cartoon vector style, featuring bright yellow colors and soft lighting, with a clean and vibrant appearance, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-uDV9ejjBYSQq5npFKv1NiIy7.png?st=2025-06-10T01%3A43%3A50Z&se=2025-06-10T03%3A43%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T08%3A17%3A18Z&ske=2025-06-10T08%3A17%3A18Z&sks=b&skv=2024-08-04&sig=qMzgD0eK%2BlASfaN/O1dGPNJZxf9N6gMqBE8Vshg/8Hc%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_yellow_lemon_and_a_sliced_lemon_in_the_same_illustration_style_as_the_uploaded_image_s_03_avocado_1png_match_the_lighting_colors_and_vector_look.png
# Processing: test_images/04_Banana.png
# Caption output: {
#   "caption": "A bunch of three ripe bananas with a glossy surface, illustrated in a vibrant flat cartoon vector style, featuring bright yellow colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 3,
#   "background": "no background",
#   "image_path": "path/to/banana_image.png",
#   "user_prompt": "Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.",
#   "generated_image_path": "path/to/generated_apricot_image.png"
# }
# Generating new image from combined prompt: Draw an apricot with a glossy surface in the same cartoon vector style as the image I uploaded.. Strictly draw 3 in flat cartoon vector style. Ensure all of them follow this description: A bunch of three ripe bananas with a glossy surface, illustrated in a vibrant flat cartoon vector style, featuring bright yellow colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-jftY2gtlugZR97GYhq9F9YBh.png?st=2025-06-10T01%3A44%3A13Z&se=2025-06-10T03%3A44%3A13Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-10T02%3A44%3A13Z&ske=2025-06-11T02%3A44%3A13Z&sks=b&skv=2024-08-04&sig=ueWj/d6gsQakbwjfyIoZEPVkuFf1bkh3In2Ol58jdgA%3D
# Saved generated image to outputs/base_prompt_improved/draw_an_apricot_with_a_glossy_surface_in_the_same_cartoon_vector_style_as_the_image_i_uploaded.png
# Processing: test_images/05_Black_currant.png
# Caption output: {
#   "caption": "A single, large, round black currant with a glossy surface, depicted in a flat cartoon vector style, featuring vibrant colors and soft lighting, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.",
#   "generated_image_path": "<your generated image path>"
# }
# Generating new image from combined prompt: Using the same style as the provided cluster of black currants, draw a single, big, round, one black currant.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A single, large, round black currant with a glossy surface, depicted in a flat cartoon vector style, featuring vibrant colors and soft lighting, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-GlmNNCxLJIjER7Qpm4DzWao6.png?st=2025-06-10T01%3A44%3A40Z&se=2025-06-10T03%3A44%3A40Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T16%3A39%3A22Z&ske=2025-06-10T16%3A39%3A22Z&sks=b&skv=2024-08-04&sig=RKXCLM2z3QG9HliLgLjSXAYSzrTo0KD/a1EWQ3R8WEo%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_style_as_the_provided_cluster_of_black_currants_draw_a_single_big_round_one_black_currant.png
# Processing: test_images/15_Grapes.png
# Caption output: ```json
# {
#   "caption": "A cluster of glossy black currants, depicted in a vibrant flat cartoon vector style, showcasing their rich black color and shiny surface, with green leaves accentuating the berries, soft lighting enhancing the glossy effect, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Draw a cluster of glossy black currants in the same cartoon vector style as the grapes image I uploaded.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A cluster of glossy black currants, depicted in a vibrant flat cartoon vector style, showcasing their rich black color and shiny surface, with green leaves accentuating the berries, soft lighting enhancing the glossy effect, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-TNklnsXLLPdg9YSaC5Ru58AX.png?st=2025-06-10T01%3A45%3A09Z&se=2025-06-10T03%3A45%3A09Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T21%3A01%3A43Z&ske=2025-06-10T21%3A01%3A43Z&sks=b&skv=2024-08-04&sig=WUs9NYvhpdGQ3lPRHUhwsED6GoVhAkzacDA2DDdCDZc%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_cluster_of_glossy_black_currants_in_the_same_cartoon_vector_style_as_the_grapes_image_i_uploaded.png
# Processing: test_images/30_Salmon.png
# Caption output: ```json
# {
#   "caption": "A sliced salmon fillet with a smooth, pink interior and a slightly darker outer layer, illustrated in a flat cartoon vector style, featuring vibrant colors and soft lighting, with no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: Draw a sliced salmon fillet in the exact same illustration style as the whole salmon image I uploaded. Match the cartoon vector look, colors, and outlines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A sliced salmon fillet with a smooth, pink interior and a slightly darker outer layer, illustrated in a flat cartoon vector style, featuring vibrant colors and soft lighting, with no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-i5VPF3rIhiW2knXlmVvvtO7Y.png?st=2025-06-10T01%3A45%3A34Z&se=2025-06-10T03%3A45%3A34Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T10%3A20%3A41Z&ske=2025-06-10T10%3A20%3A41Z&sks=b&skv=2024-08-04&sig=VqmRoAuWmJyLBq8nD1YvADgastOFb%2B3vhLkKBCM88dI%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_sliced_salmon_fillet_in_the_exact_same_illustration_style_as_the_whole_salmon_image_i_uploaded_match_the_cartoon_vector_look_colors_and_outlines.png
# Processing: test_images/35_Catfish.png
# Caption output: ```json
# {
#   "caption": "A salmon illustrated in the same style as the catfish image, featuring vibrant shades of pink and orange with smooth vector lines and soft shading, showcasing its sleek body and distinctive fins, in flat cartoon vector style, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "35_Catfish.png",
#   "user_prompt": "Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.",
#   "generated_image_path": "generated_salmon_image.png"
# }
# ```
# Generating new image from combined prompt: Draw a salmon in the same drawing style as the catfish image I uploaded (35_Catfish.png). Ensure the illustration matches the style exactly in colors, shading, and vector lines.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A salmon illustrated in the same style as the catfish image, featuring vibrant shades of pink and orange with smooth vector lines and soft shading, showcasing its sleek body and distinctive fins, in flat cartoon vector style, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-mIB7GE464qQvD9XHCLYFYjIT.png?st=2025-06-10T01%3A46%3A01Z&se=2025-06-10T03%3A46%3A01Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T15%3A57%3A42Z&ske=2025-06-10T15%3A57%3A42Z&sks=b&skv=2024-08-04&sig=QJn1cpM8A7ta5OpzWqLYFSITUGcqVjk9zCRJNeU2PM0%3D
# Saved generated image to outputs/base_prompt_improved/draw_a_salmon_in_the_same_drawing_style_as_the_catfish_image_i_uploaded_35_catfishpng_ensure_the_illustration_matches_the_style_exactly_in_colors_shading_and_vector_lines.png
# Processing: test_images/S_30_Orange_1.png
# Caption output: ```json
# {
#   "caption": "A vibrant green sliced avocado with a smooth surface, illustrated in a flat cartoon vector style, featuring soft lighting and vivid colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "S_30_Orange_1.png",
#   "user_prompt": "Using the same illustration style as the orange slice image I uploaded, draw a vibrant green sliced avocado with a smooth surface.",
#   "generated_image_path": "generated_avocado_image.png"
# }
# ```
# Generating new image from combined prompt: Using the same illustration style as the orange slice image I uploaded (S_30_Orange_1.png), draw a vibrant green sliced avocado with a smooth surface. Match the exact visual style.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A vibrant green sliced avocado with a smooth surface, illustrated in a flat cartoon vector style, featuring soft lighting and vivid colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-RhxPuI6rmovRUjy6uYsOpjQf.png?st=2025-06-10T01%3A46%3A25Z&se=2025-06-10T03%3A46%3A25Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T18%3A57%3A33Z&ske=2025-06-10T18%3A57%3A33Z&sks=b&skv=2024-08-04&sig=c2cz890guHgBP8N4PsBwdPTyMxzc7gI4N5snpV06sb0%3D
# Saved generated image to outputs/base_prompt_improved/using_the_same_illustration_style_as_the_orange_slice_image_i_uploaded_s_30_orange_1png_draw_a_vibrant_green_sliced_avocado_with_a_smooth_surface_match_the_exact_visual_style.png
# Processing: test_images/S_05_Black currant_3.png
# Caption output: ```json
# {
#   "caption": "A green pear with a smooth skin and a slightly curved shape, illustrated in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "path/to/black_currant_image.png",
#   "user_prompt": "This is a black currant. Draw me a green pear. Use the same image drawing style in the image.",
#   "generated_image_path": "path/to/generated_green_pear_image.png"
# }
# ```
# Generating new image from combined prompt: This is a  black currant . Draw me a green pear. Use the same image drawing style in the image.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A green pear with a smooth skin and a slightly curved shape, illustrated in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-ReXR3cq4sH0dJjJxPZ61E0zC.png?st=2025-06-10T01%3A46%3A48Z&se=2025-06-10T03%3A46%3A48Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T15%3A08%3A20Z&ske=2025-06-10T15%3A08%3A20Z&sks=b&skv=2024-08-04&sig=STQUHZCBj1s0d37heiJ1Y3qA04sEex9jQdnnge%2BDHww%3D
# Saved generated image to outputs/base_prompt_improved/this_is_a_black_currant_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image.png
# Processing: test_images/S_11_Cranbverry_1.png
# Caption output: ```json
# {
#   "caption": "A green pear with a smooth skin texture, depicted in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background.",
#   "drawing_style": "flat cartoon vector",
#   "quantity": 1,
#   "background": "no background",
#   "image_path": "<actual image path>",
#   "user_prompt": "This is a cranberry. Draw me a green pear.",
#   "generated_image_path": "<your generated image path>"
# }
# ```
# Generating new image from combined prompt: This is a  cranberry . Draw me a green pear. Use the same image drawing style in the image.. Strictly draw 1 in flat cartoon vector style. Ensure all of them follow this description: A green pear with a smooth skin texture, depicted in a flat cartoon vector style, featuring soft lighting and vibrant colors, no background..
# Generated image URL: https://oaidalleapiprodscus.blob.core.windows.net/private/org-9DP1r18q6yLXvWOlkzlZ3Ess/user-FraXfwg3c0aTUJi4hrjaVv1s/img-plf8TMbBHqYRxuQ4O5NH3Qlr.png?st=2025-06-10T01%3A47%3A10Z&se=2025-06-10T03%3A47%3A10Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-09T19%3A52%3A50Z&ske=2025-06-10T19%3A52%3A50Z&sks=b&skv=2024-08-04&sig=WxGvDsz/3halxbb1sBrqjX4jcDK8W67V2/U7Ul2J5Cc%3D
# Saved generated image to outputs/base_prompt_improved/this_is_a_cranberry_draw_me_a_green_pear_use_the_same_image_drawing_style_in_the_image.png
#
# --- ALL DONE ---
